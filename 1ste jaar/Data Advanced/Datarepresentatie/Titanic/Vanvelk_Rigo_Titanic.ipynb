# %%
import pandas as pd
import matplotlib as plt

titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
titanic[['class', 'embark_town', 'sex']]
# Out:
#       class  embark_town     sex
# 0     Third  Southampton    male
# 1     First    Cherbourg  female
# 2     Third  Southampton  female
# 3     First  Southampton  female
# 4     Third  Southampton    male
# ..      ...          ...     ...
# 886  Second  Southampton    male
# 887   First  Southampton  female
# 888   Third  Southampton  female
# 889   First    Cherbourg    male
# 890   Third   Queenstown    male
#
# [891 rows x 3 columns]

# %%
titanic[5:10]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
print(titanic[5:10].survived)
titanic[5:11][['survived', 'age']]
# Out:
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: survived, dtype: int64
#     survived   age
# 5          0   NaN
# 6          0  54.0
# 7          0   2.0
# 8          1  27.0
# 9          1  14.0
# 10         1   4.0

# %%
mannen = titanic [titanic['sex'] == 'male']
print(mannen)
print(len(mannen))
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
# opgave 12
eersteklassemannen = mannen[mannen['class'] == 'First']
len(eersteklassemannen)
# Out:
# 122

# %%
# opgave 13
titanic.sex.value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
#opgave 14
titanic.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
titanic[titanic.embark_town.isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# opgave 15
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# opgave 16
titanic.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
# opgave 17
print(titanice.fare.mean())
print(titanic.fare.median())

# %%
overlevend = titanic.survived.value_counts()
overlevend.plot.pie(title = 'overlevenden', figsize=(4,4), autopct='%2.0f%%')
# Out:
# <AxesSubplot:title={'center':'overlevenden'}, ylabel='survived'>

# %%
mannen = titanic[titanic.sex == 'male'].survived
mannen.value_counts().plot.pie(title = 'mannen overlevenden', figsize=(4,4), autopct='%2.1f%%')
# Out:
# <AxesSubplot:title={'center':'mannen overlevenden'}, ylabel='survived'>

# %%
vrouwen = titanic[titanic.sex == 'female'].survived
vrouwen.value_counts().plot.pie(title = 'vrouwen overlevenden', figsize=(4,4), autopct='%2.1f%%')
# Out:
# <AxesSubplot:title={'center':'vrouwen overlevenden'}, ylabel='survived'>

# %%
klasse = titanic.pclass
klasse.value_counts().plot.bar(title = 'aantal per klasse', figsize=(4,4), color='r')
# Out:
# <AxesSubplot:title={'center':'aantal per klasse'}>

# %%
# opgave 21
mannen = titanic[titanic.sex == 'male']['pclass']
mannen.value_counts().plot.bar(title = 'mannen per klasse', figsize=(6,3), rot=0)
# Out:
# <AxesSubplot:title={'center':'mannen per klasse'}>

# %%
vrouwen = titanic[titanic.sex == 'female']['pclass']
vrouwen.value_counts().plot.bar(title = 'vrouwen per klasse', figsize=(6,3), rot=0)
# Out:
# <AxesSubplot:title={'center':'vrouwen per klasse'}>

# %%
# opgave 22
leeftijd = titanic.age
leeftijd.plot.hist(title = 'leeftijd passagiers', figsize=(6,4))
# Out:
# <AxesSubplot:title={'center':'leeftijd passagiers'}, ylabel='Frequency'>

# %%
# opgave 23
titanic.fare.plot.hist(title='fare', bins=20)
# Out:
# <AxesSubplot:title={'center':'fare'}, ylabel='Frequency'>

# %%
# opgave 25
titanic.age.plot.box(title='age')
# Out:
# <AxesSubplot:title={'center':'age'}>

# %%
titanic.boxplot('age')
# Out:
# <AxesSubplot:>

# %%
# opgave 26
titanic.boxplot('age', 'pclass')
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='pclass'>

# %%
# opgave 28
pd.crosstab(titanic.sex, titanic.pclass)
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
# opgave 29
pd.crosstab(titanic.sex, titanic.pclass, values=titanic.age, aggfunc='mean', margins = True)
# Out:
# pclass          1          2          3        All
# sex
# female  34.611765  28.722973  21.750000  27.915709
# male    41.281386  30.740707  26.507589  30.726645
# All     38.233441  29.877630  25.140620  29.699118

# %%
titanic.pivot_table(index = 'sex', columns='pclass', values='age', aggfunc='mean', margins=True)
# Out:
# pclass          1          2          3        All
# sex
# female  34.611765  28.722973  21.750000  27.915709
# male    41.281386  30.740707  26.507589  30.726645
# All     38.233441  29.877630  25.140620  29.699118

# %%
# opgave 30
titanic.plot.scatter(x = 'age', y = 'fare')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
#opgave 31
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(), annot = True, cmap="coolwarm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-16f8aa7c8940> in <module>
# ----> 1 sns.heatmap(titanic.corr(), annot = True, cmap="coolwarm")
#
# NameError: name 'sns' is not defined

# %%
#32
titanic[titanic.embarked.isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
#34
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
#34 alt
titanic.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
#35
pd.crosstab(titanic.embarked, titanic.survived)
# Out:
# survived    0    1
# embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
#35 alt
titanic[titanic.survived == 1]['embarked'].value_counts()
# Out:
# S    217
# C     93
# Q     30
# Name: embarked, dtype: int64

# %%
#36
pd.crosstab(titanic.pclass, titanic.embarked, values = titanic.fare, aggfunc='median')
# Out:
# embarked        C      Q      S
# pclass
# 1         78.2667  90.00  52.00
# 2         24.0000  12.35  13.50
# 3          7.8958   7.75   8.05

# %%
#37
titanic.loc[titanic.embarked.isnull(), 'embarked'] = 'C'
titanic[titanic.embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
#38
len(titanic[titanic.age.isnull()])
# Out:
# 177

# %%
titanic.loc[titanic['age'].isnull()].sample(10)
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked   class  \
# 364         0       3    male  NaN      1      0   15.5000        Q   Third
# 766         0       1    male  NaN      0      0   39.6000        C   First
# 431         1       3  female  NaN      1      0   16.1000        S   Third
# 180         0       3  female  NaN      8      2   69.5500        S   Third
# 306         1       1  female  NaN      0      0  110.8833        C   First
# 863         0       3  female  NaN      8      2   69.5500        S   Third
# 186         1       3  female  NaN      1      0   15.5000        Q   Third
# 481         0       2    male  NaN      0      0    0.0000        S  Second
# 260         0       3    male  NaN      0      0    7.7500        Q   Third
# 77          0       3    male  NaN      0      0    8.0500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 364    man        True  NaN   Queenstown    no  False
# ...

# %%
#39
titanic.age.plot.hist('leeftijd')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
mannen = titanic[titanic.sex == 'male']
mannen.age.plot.hist('mannen leeftijd')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vrouwen = titanic[titanic.sex == 'female']
vrouwen.age.plot.hist('vrouwen leeftijd')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#39
titanic.groupby(['sex']).age.median()
# Out:
# sex
# female    27.0
# male      29.0
# Name: age, dtype: float64

# %%
titanic.boxplot(by='sex', column='age')
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='sex'>

# %%
#40
titanic.boxplot('age', 'pclass')
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='pclass'>

# %%
#41
pclass_age_median = titanic.groupby('pclass').age.transform('median')
print(pclass_age_median)
titanic.age.fillna(pclass_age_median, inplace=True)
# Out:
# 0      24.0
# 1      37.0
# 2      24.0
# 3      37.0
# 4      24.0
#        ...
# 886    29.0
# 887    37.0
# 888    24.0
# 889    37.0
# 890    24.0
# Name: age, Length: 891, dtype: float64

# %%
#42
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
#44
titanic.fare.plot.hist(title='prijs', bins=20)
# Out:
# <AxesSubplot:title={'center':'prijs'}, ylabel='Frequency'>

# %%
#45
titanic.fare.plot.box('fare')
# Out:
# <AxesSubplot:>

# %%
#46
titanic[titanic.fare == titanic.fare.max()]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
#47
# outliers deleten
# binning; we gaan van de fare een categorische variabele maken door die in 4 groepen op te delen

# %%
#48
pd.qcut(titanic['fare'], 4)
# Out:
# 0       (-0.001, 7.91]
# 1      (31.0, 512.329]
# 2       (7.91, 14.454]
# 3      (31.0, 512.329]
# 4       (7.91, 14.454]
#             ...
# 886     (7.91, 14.454]
# 887     (14.454, 31.0]
# 888     (14.454, 31.0]
# 889     (14.454, 31.0]
# 890     (-0.001, 7.91]
# Name: fare, Length: 891, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.91] < (7.91, 14.454] < (14.454, 31.0] < (31.0, 512.329]]

# %%
pd.qcut(titanic['fare'], 4, labels=['zeer laag', 'laag', 'hoog', 'zeer hoog'])
# Out:
# 0      zeer laag
# 1      zeer hoog
# 2           laag
# 3      zeer hoog
# 4           laag
#          ...
# 886         laag
# 887         hoog
# 888         hoog
# 889         hoog
# 890    zeer laag
# Name: fare, Length: 891, dtype: category
# Categories (4, object): ['zeer laag' < 'laag' < 'hoog' < 'zeer hoog']

# %%
#49
pd.qcut(titanic['fare'], 4, labels=['zeer laag', 'laag', 'hoog', 'zeer hoog']).value_counts()
# Out:
# laag         224
# zeer laag    223
# zeer hoog    222
# hoog         222
# Name: fare, dtype: int64

# %%
pd.qcut(titanic['fare'], 4, labels=['zeer laag', 'laag', 'hoog', 'zeer hoog']).value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
#50
titanic['fare_category'] = pd.qcut(titanic['fare'], 4, labels=['zeer laag', 'laag', 'hoog', 'zeer hoog'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   survived       891 non-null    int64
#  1   pclass         891 non-null    int64
#  2   sex            891 non-null    object
#  3   age            891 non-null    float64
#  4   sibsp          891 non-null    int64
#  5   parch          891 non-null    int64
#  6   fare           891 non-null    float64
#  7   embarked       891 non-null    object
#  8   class          891 non-null    object
#  9   who            891 non-null    object
#  10  adult_male     891 non-null    bool
#  11  deck           203 non-null    object
#  12  embark_town    889 non-null    object
#  13  alive          891 non-null    object
#  14  alone          891 non-null    bool
#  15  fare_category  891 non-null    category
# dtypes: bool(2), category(1), float64(2), int64(4), object(7)
# ...

# %%
#51
titanice = pd.read_csv('titanic.csv')
titanice.fare.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#52
import matplotlib.pyplot as plt
titanic.fare.plot.kde()
plt.xlabel("fare")
plt.ylabel("dichtheid")
# Out:
# Text(0, 0.5, 'dichtheid')

# %%
ax = plt.gca()
ax.set_xlim(-30, 250)
titanic.fare.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#53
titanic.fare.skew()
# Out:
# 4.787316519674893

# %%
#54
titanic.age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#55
titanic.age.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#56 skewness paramter voor age
titanic.age.skew()
# Out:
# 0.38910778230082704

# %%
#57
print(titanic.age.mean())
print(titanic.age.std())
# Out:
# 29.69911764705882
# 14.526497332334044

# %%
#58
import scipy.stats as stats
import math
stats.norm.cdf(30, titanic.age.mean(), titanic.age.std()) - stats.norm.cdf(20, titanic.age.mean(), titanic.age.std())
# Out:
# 0.2560950724977453

# %%
#59
data = titanic[(titanic.age >= 20) & (titanic.age <=30)]
len(data)
# Out:
# 245

# %%
len(data)/len(titanic)
# Out:
# 0.27497194163860833
